# %% [markdown]
# # Assigment 2

# %% [markdown]
# ## Analysing Data base

# %%
import pandas as pd
import sqlite3

# %%
try:
    connection=sqlite3.connect('lahman2014.sqlite')
except Error as e:
    print(e)

# %%
# We found that we have only salary from period 1985 to 2014\
#SO,first we extracted data of teams between this period to analyze it
teamPandas=pd.read_sql_query("""SELECT yearID,teamID,Rank,G,W,name FROM Teams where yearID BETWEEN 1985 and 2014""",connection)
teamPandas.head()
# Out:
#    yearID teamID  Rank    G   W               name
# 0    1985    BAL     4  161  83  Baltimore Orioles
# 1    1985    BOS     5  163  81     Boston Red Sox
# 2    1985    CAL     2  162  90  California Angels
# 3    1985    CHA     3  163  85  Chicago White Sox
# 4    1985    CLE     7  162  60  Cleveland Indians

# %%
#Reading data of salaries
salaryPandas=pd.read_sql_query("""SELECT * FROM Salaries""",connection)
salaryPandas.head()
# Out:
#    yearID teamID lgID   playerID    salary
# 0    1985    ATL   NL  barkele01  870000.0
# 1    1985    ATL   NL  bedrost01  550000.0
# 2    1985    ATL   NL  benedbr01  545000.0
# 3    1985    ATL   NL   campri01  633333.0
# 4    1985    ATL   NL  ceronri01  625000.0

# %%
dictionaryOfTeams={}
for i in teamPandas.itertuples():
    if i[2] not in dictionaryOfTeams:
        #2 for teamId
        #4 for gamePlay
        #5 for wining
        dictionaryOfTeams[i[2]]=[i[4],i[5],0]
    else:
        dictionaryOfTeams[i[2]][0]+=i[4]
        dictionaryOfTeams[i[2]][1]+=i[5]
#For loop to add all salaries to leagueTeams
for i in salaryPandas.itertuples():
    if i[2] not in dictionaryOfTeams:
        continue
    dictionaryOfTeams[i[2]][2]+=i[5]

# %%
len(dictionaryOfTeams)
# Out:
# 35

# %%
#Just merging data by pandas to ensure that data from sql is right
TeamPayRoll1=pd.DataFrame.from_dict(dictionaryOfTeams, orient='index',columns=['Playing', 'Winning','Total payRolls in million'])

# %%
TeamPayRoll1['Total payRolls in million'] = TeamPayRoll1['Total payRolls in million'].astype(float)
TeamPayRoll1['Total payRolls in million']/=1000000

# %%
TeamPayRoll1['WinRate']=TeamPayRoll1.Winning/TeamPayRoll1.Playing

# %%
TeamPayRoll1.head()
# Out:
#      Playing  Winning  Total payRolls in million   WinRate
# BAL     4790     2265                1630.200038  0.472860
# BOS     4794     2576                2432.700935  0.537338
# CAL     1879      922                 271.978930  0.490687
# CHA     4794     2435                1699.865143  0.507927
# CLE     4792     2389                1405.016128  0.498539

# %%
#those teams have different names in teamDataBase and salary data base 
notFoundTeams=[]
for i in salaryPandas.itertuples():
     if i[2] not in dictionaryOfTeams and i[2]not in notFoundTeams:
            notFoundTeams.append(i[2])
notFoundTeams
# Out:
# ['NYM', 'SFG']

# %% [markdown]
# ## Part 1

# %%
teamPayRoll2=pd.read_sql_query(""" 
SELECT Teams.teamID,Teams.name, CAST(sum(Teams.W) AS FLOAT)/CAST(sum(Teams.G) AS FLOAT) AS 'WinningRatio', sum(salary)/1000000 AS 'Total Pay in Million'
FROM Teams Left join Salaries
ON Teams.teamID = Salaries.teamID And Teams.yearID = Salaries.yearID
GROUP BY Teams.teamID
""",connection)

# %%
teamPayRoll2.head()
# Out:
#   teamID                   name  WinningRatio  Total Pay in Million
# 0    ALT  Altoona Mountain City      0.240000                   NaN
# 1    ANA         Anaheim Angels      0.508297            468.091973
# 2    ARI   Arizona Diamondbacks      0.493687           1209.975228
# 3    ATL         Atlanta Braves      0.540464           1882.946784
# 4    BAL      Baltimore Orioles      0.476154           1630.200038

# %%
teamPayRoll2.loc[teamPayRoll2.teamID=='SFN']
# Out:
#     teamID                  name  WinningRatio  Total Pay in Million
# 116    SFN  San Francisco Giants      0.519432           1696.242921

# %%
teamPayRoll2.loc[teamPayRoll2.teamID=='SFN']
# Out:
#     teamID                  name  WinningRatio  Total Pay in Million
# 116    SFN  San Francisco Giants      0.519432           1696.242921

# %%
teamPayRoll2.loc[teamPayRoll2.teamID=='NYN']
# Out:
#    teamID           name  WinningRatio  Total Pay in Million
# 93    NYN  New York Mets      0.508664           1965.737231

# %%
teamPayRoll2=teamPayRoll2.drop(teamPayRoll2.index[93])
teamPayRoll2=teamPayRoll2.drop(teamPayRoll2.index[116])

# %%
newSfn=pd.read_sql_query(""" 
SELECT Teams.teamID,name,Cast(sum(w) AS FLOAT)/sum(g) as'WinningRatio',sum(salary)/1000000 AS 'Total Pay in Million'
FROM Teams,Salaries
where (teamidbr='SFG' or teamidbr='NYM' )and teams.yearID=Salaries.yearID AND (teams.teamID=Salaries.teamID or Salaries.teamid=teams.teamidbr)and Teams.yearid between 1985 and 2014
group by teamidbr
""",connection)

# %%
newSfn
# Out:
#   teamID                  name  WinningRatio  Total Pay in Million
# 0    NYN         New York Mets      0.510081           2020.544221
# 1    SFN  San Francisco Giants      0.520245           1839.753088

# %%
lastPayRoll=pd.concat([teamPayRoll2, newSfn])

# %%
lastPayRoll.to_csv('lastPayRoll.csv')

# %%
lastPayRoll.head()
# Out:
#   teamID                   name  WinningRatio  Total Pay in Million
# 0    ALT  Altoona Mountain City      0.240000                   NaN
# 1    ANA         Anaheim Angels      0.508297            468.091973
# 2    ARI   Arizona Diamondbacks      0.493687           1209.975228
# 3    ATL         Atlanta Braves      0.540464           1882.946784
# 4    BAL      Baltimore Orioles      0.476154           1630.200038

# %%
df = lastPayRoll.dropna();df.head()
# Out:
#    teamID                  name  WinningRatio  Total Pay in Million
# 1     ANA        Anaheim Angels      0.508297            468.091973
# 2     ARI  Arizona Diamondbacks      0.493687           1209.975228
# 3     ATL        Atlanta Braves      0.540464           1882.946784
# 4     BAL     Baltimore Orioles      0.476154           1630.200038
# 15    BOS      Boston Americans      0.534566           2432.700935

# %%
import plotly.express as px
fig = px.scatter(df, y="WinningRatio", x="Total Pay in Million", color='name')
fig.show()
# Out:
# <div>
#
#
#             <div id="c4df9dc3-45dd-4292-8b6d-4763c31a1d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4df9dc3-45dd-4292-8b6d-4763c31a1d97")) {
#                     Plotly.newPlot(
#                         'c4df9dc3-45dd-4292-8b6d-4763c31a1d97',
# ...

# %%
teams_payroll=pd.read_sql_query("""SELECT teamid,yearid,sum(Salary)/1000000 as 'Salary in M' from Salaries
where yearid >= 1990
group by yearid,teamid""",connection)

# %%
teams_payroll.head()
# Out:
#   teamID  yearID  Salary in M
# 0    ATL    1990    14.555501
# 1    BAL    1990     9.680084
# 2    BOS    1990    20.558333
# 3    CAL    1990    21.720000
# 4    CHA    1990     9.491500

# %%
fig = px.scatter(teams_payroll, x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="77889f12-15f3-42fb-8001-eaba89c0da80" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("77889f12-15f3-42fb-8001-eaba89c0da80")) {
#                     Plotly.newPlot(
#                         '77889f12-15f3-42fb-8001-eaba89c0da80',
# ...

# %%
fig = px.line(teams_payroll, x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="e9863969-01a5-49ee-b1bb-876eda6e3ddd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9863969-01a5-49ee-b1bb-876eda6e3ddd")) {
#                     Plotly.newPlot(
#                         'e9863969-01a5-49ee-b1bb-876eda6e3ddd',
# ...

# %%
fig = px.line(teams_payroll[teams_payroll.teamID=='NYA'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="ac0e3452-0331-4b6c-b23d-4f87bff4f015" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ac0e3452-0331-4b6c-b23d-4f87bff4f015")) {
#                     Plotly.newPlot(
#                         'ac0e3452-0331-4b6c-b23d-4f87bff4f015',
# ...

# %%
fig = px.line(teams_payroll[teams_payroll.teamID=='SFN'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="bf38de86-d946-4977-b003-b096e641b6ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf38de86-d946-4977-b003-b096e641b6ca")) {
#                     Plotly.newPlot(
#                         'bf38de86-d946-4977-b003-b096e641b6ca',
# ...

# %%
fig = px.line(teams_payroll[teams_payroll.teamID=='SFG'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="471ae18d-91be-4d7f-8d91-24412d70f5cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("471ae18d-91be-4d7f-8d91-24412d70f5cc")) {
#                     Plotly.newPlot(
#                         '471ae18d-91be-4d7f-8d91-24412d70f5cc',
#                         [{"hovertemplate": "teamID=SFG<br>yearID=%{x}<br>Salary in M=%{y}<extra></extra>", "legendgroup": "SFG", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "SFG", "showlegend": true, "type": "scatter", "x": [2014], "xaxis": "x", "y": [143.510167], "yaxis": "y"}],
# ...

# %%
df = teams_payroll.copy()

# %%
teams_payroll.loc[teams_payroll.teamID == 'SFG', 'Salary in M']
# Out:
# 723    143.510167
# Name: Salary in M, dtype: float64

# %%
val = list(teams_payroll.loc[teams_payroll.teamID == 'SFG', 'Salary in M']); val
# Out:
# [143.510167]

# %%
df.loc[(df.teamID == 'SFN') & (df.yearID == 2014), 'Salary in M']
# Out:
# 724    20.0
# Name: Salary in M, dtype: float64

# %%
df.loc[(df.teamID == 'SFN') & (df.yearID == 2014), 'Salary in M'] += val[0]

# %%
df.loc[df.teamID == 'SFN']
# Out:
#     teamID  yearID  Salary in M
# 22     SFN    1990    19.335333
# 48     SFN    1991    30.967666
# 74     SFN    1992    33.163168
# 102    SFN    1993    35.050000
# 130    SFN    1994    42.638666
# 158    SFN    1995    36.462777
# 186    SFN    1996    37.144725
# 214    SFN    1997    35.592378
# 243    SFN    1998    42.565834
# 273    SFN    1999    46.595057
# 303    SFN    2000    53.737826
# 333    SFN    2001    63.280167
# 363    SFN    2002    78.299835
# 393    SFN    2003    82.852167
# 423    SFN    2004    82.019166
# 452    SFN    2005    90.199500
# 482    SFN    2006    90.056419
# 512    SFN    2007    90.219056
# 542    SFN    2008    76.594500
# 572    SFN    2009    83.026450
# 602    SFN    2010    98.641333
# 632    SFN    2011   118.198333
# 662    SFN    2012   117.620683
# 692    SFN    2013   140.180334
# 724    SFN    2014   163.510167

# %%
fig = px.line(df[df.teamID=='SFN'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="64f62907-bdcc-4b5c-8b28-0b7e75159c5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64f62907-bdcc-4b5c-8b28-0b7e75159c5c")) {
#                     Plotly.newPlot(
#                         '64f62907-bdcc-4b5c-8b28-0b7e75159c5c',
# ...

# %%
fig = px.line(df[df.teamID=='NYN'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="ebf349a3-da33-4b40-bf40-c150ccac167d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebf349a3-da33-4b40-bf40-c150ccac167d")) {
#                     Plotly.newPlot(
#                         'ebf349a3-da33-4b40-bf40-c150ccac167d',
# ...

# %%
teams_payroll[teams_payroll.teamID == 'NYN']
# Out:
#     teamID  yearID  Salary in M
# 16     NYN    1990    21.722834
# 42     NYN    1991    32.590001
# 68     NYN    1992    44.602002
# 96     NYN    1993    39.043667
# 124    NYN    1994    30.956583
# 152    NYN    1995    27.674992
# 180    NYN    1996    24.479500
# 208    NYN    1997    39.800400
# 237    NYN    1998    52.077999
# 267    NYN    1999    65.092092
# 297    NYN    2000    79.509776
# 327    NYN    2001    93.174428
# 357    NYN    2002    94.633593
# 387    NYN    2003   116.876429
# 417    NYN    2004    96.660970
# 446    NYN    2005   101.305821
# 476    NYN    2006   101.084963
# 506    NYN    2007   115.231663
# 536    NYN    2008   137.793376
# 566    NYN    2009   149.373987
# 596    NYN    2010   134.422942
# 626    NYN    2011   118.847309
# 656    NYN    2012    93.353983
# 686    NYN    2013    49.448346
# 717    NYN    2014    30.750000

# %%
teams_payroll[teams_payroll.teamID == 'NYM']
# Out:
#     teamID  yearID  Salary in M
# 716    NYM    2014     54.80699

# %%
val = list(teams_payroll.loc[teams_payroll.teamID == 'NYM', 'Salary in M']); val
df.loc[(df.teamID == 'NYN') & (df.yearID == 2014), 'Salary in M'] += val[0]

# %%
df.loc[df.teamID == 'NYN']
# Out:
#     teamID  yearID  Salary in M
# 16     NYN    1990    21.722834
# 42     NYN    1991    32.590001
# 68     NYN    1992    44.602002
# 96     NYN    1993    39.043667
# 124    NYN    1994    30.956583
# 152    NYN    1995    27.674992
# 180    NYN    1996    24.479500
# 208    NYN    1997    39.800400
# 237    NYN    1998    52.077999
# 267    NYN    1999    65.092092
# 297    NYN    2000    79.509776
# 327    NYN    2001    93.174428
# 357    NYN    2002    94.633593
# 387    NYN    2003   116.876429
# 417    NYN    2004    96.660970
# 446    NYN    2005   101.305821
# 476    NYN    2006   101.084963
# 506    NYN    2007   115.231663
# 536    NYN    2008   137.793376
# 566    NYN    2009   149.373987
# 596    NYN    2010   134.422942
# 626    NYN    2011   118.847309
# 656    NYN    2012    93.353983
# 686    NYN    2013    49.448346
# 717    NYN    2014    85.556990

# %%
fig = px.line(df[df.teamID=='NYN'], x="yearID", y="Salary in M", color='teamID')
fig.show()
# Out:
# <div>
#
#
#             <div id="cb00119b-4a40-4c75-b4c3-0a361a773c9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb00119b-4a40-4c75-b4c3-0a361a773c9a")) {
#                     Plotly.newPlot(
#                         'cb00119b-4a40-4c75-b4c3-0a361a773c9a',
# ...

# %% [markdown]
# https://legacy.baseballprospectus.com/compensation/cots/national-league/new-york-mets/

# %%
df.index[716]
# Out:
# 716

# %%
df.loc[716]
# Out:
# teamID            NYM
# yearID           2014
# Salary in M    54.807
# Name: 716, dtype: object

# %%
df.index[723]
# Out:
# 723

# %%
df.iloc[723]
# Out:
# teamID            SFG
# yearID           2014
# Salary in M    143.51
# Name: 723, dtype: object

# %%
#df=df.drop(df.index[716])
#df=df.drop(df.index[723])
df = df.drop(df[df.teamID=='SFG'].index)
df = df.drop(df[df.teamID=='NYM'].index)

# %%
df.loc[710:730]
# Out:
#     teamID  yearID  Salary in M
# 710    LAA    2014   121.988250
# 711    LAN    2014   217.014600
# 712    MIA    2014    41.836900
# 713    MIL    2014   101.217000
# 714    MIN    2014    83.762500
# 715    NYA    2014   197.543907
# 717    NYN    2014    85.556990
# 718    OAK    2014    72.408400
# 719    PHI    2014   180.944967
# 720    PIT    2014    77.178000
# 721    SDN    2014    75.685700
# 722    SEA    2014    92.531100
# 724    SFN    2014   163.510167
# 725    SLN    2014   120.693000
# 726    TBA    2014    72.689100
# 727    TEX    2014   112.255059
# 728    TOR    2014   109.920100
# 729    WAS    2014   131.983680

# %%
len(set(df.teamID))
# Out:
# 35

# %%
teamID = list(set(df.teamID)); teamID
# Out:
# ['TOR',
#  'NYN',
#  'LAA',
#  'ATL',
#  'BOS',
#  'TBA',
#  'KCA',
#  'MON',
#  'MIL',
#  'HOU',
#  'PHI',
#  'FLO',
#  'ML4',
#  'MIA',
#  'LAN',
#  'DET',
#  'ANA',
#  'CIN',
#  'TEX',
#  'SDN',
#  'SFN',
#  'CHA',
#  'WAS',
#  'OAK',
#  'PIT',
#  'CHN',
#  'BAL',
#  'NYA',
#  'CLE',
#  'SLN',
#  'MIN',
#  'COL',
#  'ARI',
#  'SEA',
#  'CAL']

# %%
for i in range(0, 35, 7):
    fig = px.line(df[df['teamID'].isin(teamID[i:i+7])], x="yearID", y="Salary in M", color='teamID')
    fig.show()
# Out:
# <div>
#
#
#             <div id="b57c214a-7420-42ae-9947-e6ae0a7f0ca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b57c214a-7420-42ae-9947-e6ae0a7f0ca0")) {
#                     Plotly.newPlot(
#                         'b57c214a-7420-42ae-9947-e6ae0a7f0ca0',
# ...

# %%
df.rename(columns={'Salary in M':'SalaryM'}, 
                 inplace=True)

# %%
df[df['teamID'] == 'ATL'].mean()
# Out:
# yearID         2002.000000
# Salary in M      72.426077
# dtype: float64

# %%
name_mean = {}
for name in teamID:
    name_mean[name] = df[df['teamID'] == name].SalaryM.mean()

# %%
name_mean
# Out:
# {'TOR': 60.41877456,
#  'NYN': 77.81258584,
#  'LAA': 118.46716860000001,
#  'ATL': 72.4260772,
#  'BOS': 94.63516516000001,
#  'TBA': 45.182992647058825,
#  'KCA': 44.4013562,
#  'MON': 23.8184814,
#  'MIL': 61.65653252941178,
#  'HOU': 53.93211168,
#  'PHI': 76.98737739999999,
#  'FLO': 35.527158157894725,
#  'ML4': 23.148728874999996,
#  'MIA': 64.5056,
#  'LAN': 86.4115012,
#  'DET': 68.33499896,
#  'ANA': 58.51149662499999,
#  'CIN': 55.41068536000001,
#  'TEX': 65.50219868,
#  'SDN': 44.81043551999999,
#  'SFN': 71.51806160000001,
#  'CHA': 66.21211572,
#  'WAS': 71.53600209999999,
#  'OAK': 45.229300679999994,
#  'PIT': 37.92352872,
#  'CHN': 71.67308143999999,
#  'BAL': 62.797222119999994,
#  'NYA': 127.86926543999998,
#  'CLE': 54.564408480000004,
#  'SLN': 68.52889624,
#  'MIN': 48.85329216,
#  'COL': 58.814119954545454,
#  'ARI': 71.17501341176471,
#  'SEA': 65.72746688000001,
#  'CAL': 29.033579714285715}

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(name_mean.keys(), name_mean.values())
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
plt.hist(name_mean.values())
# Out:
# (array([ 3.,  2.,  7.,  7., 10.,  2.,  2.,  0.,  0.,  2.]),
#  array([ 23.14872887,  33.62078253,  44.09283619,  54.56488984,
#          65.0369435 ,  75.50899716,  85.98105081,  96.45310447,
#         106.92515813, 117.39721178, 127.86926544]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Correlation

# %%
df.yearID.max(), df.yearID.min()
# Out:
# (2014, 1990)

# %%
new_df=pd.read_sql_query(""" 
select teamid, yearid, CAST(Teams.W AS FLOAT)/CAST(Teams.G AS FLOAT) AS 'WinningRatio' from Teams
where yearid >= 1990
GROUP by yearid, teamid
""",connection)

# %%
new_df.head()
# Out:
#   teamID  yearID  WinningRatio
# 0    ATL    1990      0.401235
# 1    BAL    1990      0.472050
# 2    BOS    1990      0.543210
# 3    CAL    1990      0.493827
# 4    CHA    1990      0.580247

# %%
df.head()
# Out:
#   teamID  yearID    SalaryM
# 0    ATL    1990  14.555501
# 1    BAL    1990   9.680084
# 2    BOS    1990  20.558333
# 3    CAL    1990  21.720000
# 4    CHA    1990   9.491500

# %%
merged_df = pd.merge(df, new_df, left_on=['teamID', 'yearID'], right_on=['teamID', 'yearID'])

# %%
merged_df[merged_df.teamID =='ANA']
# Out:
#     teamID  yearID     SalaryM  WinningRatio
# 190    ANA    1997   31.135472      0.518519
# 218    ANA    1998   41.281000      0.524691
# 248    ANA    1999   55.388166      0.432099
# 278    ANA    2000   51.464167      0.506173
# 308    ANA    2001   47.535167      0.462963
# 338    ANA    2002   61.721667      0.611111
# 368    ANA    2003   79.031667      0.475309
# 398    ANA    2004  100.534667      0.567901

# %%
years = list(set(merged_df.yearID))

# %%
len(years)
# Out:
# 25

# %%
len(years)//5
# Out:
# 5

# %%
pd.DataFrame({'teamID':[]})
# Out:
# Empty DataFrame
# Columns: [teamID]
# Index: []

# %%
merged_df.head()
# Out:
#   teamID  yearID    SalaryM  WinningRatio
# 0    ATL    1990  14.555501      0.401235
# 1    BAL    1990   9.680084      0.472050
# 2    BOS    1990  20.558333      0.543210
# 3    CAL    1990  21.720000      0.493827
# 4    CHA    1990   9.491500      0.580247

# %%
for i in range(0, 25, 5):
    ddd = merged_df[merged_df['yearID'].isin(years[i:i+5])]
    ddd = ddd.groupby(['teamID']).mean()
    ddd['teamID'] = ddd.index
    fig = px.scatter(ddd, x="SalaryM", y="WinningRatio", color='teamID')
    fig.show()
# Out:
# <div>
#
#
#             <div id="a2ab7ec0-068c-4760-bf61-03f756ad6a25" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2ab7ec0-068c-4760-bf61-03f756ad6a25")) {
#                     Plotly.newPlot(
#                         'a2ab7ec0-068c-4760-bf61-03f756ad6a25',
# ...

# %%
ddd.head()
# Out:
#   teamID  yearID    SalaryM  WinningRatio
# 0    ATL    1990  14.555501      0.401235
# 1    BAL    1990   9.680084      0.472050
# 2    BOS    1990  20.558333      0.543210
# 3    CAL    1990  21.720000      0.493827
# 4    CHA    1990   9.491500      0.580247

# %%
df.groupby(['yearID']).mean().plot()

# %%
ddd.tail()
# Out:
#     teamID  yearID    SalaryM
# 129    SEA    1994  29.228500
# 130    SFN    1994  42.638666
# 131    SLN    1994  29.275601
# 132    TEX    1994  32.973597
# 133    TOR    1994  43.433668

# %%
ddd = merged_df[merged_df['yearID'].isin(years[i:i+5])]
ddd = ddd.groupby(['teamID']).mean()

# %%
ddd['teamID'] = ddd.index

# %%
ddd
# Out:
#         yearID    SalaryM  WinningRatio teamID
# teamID
# ATL     1992.0  31.721853      0.564977    ATL
# BAL     1992.0  23.785204      0.504441    BAL
# BOS     1992.0  34.863217      0.495148    BOS
# CAL     1992.0  28.654777      0.457048    CAL
# CHA     1992.0  27.090400      0.564263    CHA
# CHN     1992.0  28.460670      0.477401    CHN
# CIN     1992.0  32.489666      0.519721    CIN
# CLE     1992.0  18.109309      0.469901    CLE
# COL     1993.5  17.120417      0.433286    COL
# DET     1992.0  29.670214      0.490939    DET
# FLO     1993.5  20.481772      0.419270    FLO
# HOU     1992.0  21.985300      0.492560    HOU
# KCA     1992.0  33.092451      0.498299    KCA
# LAN     1992.0  35.245907      0.500520    LAN
# MIN     1992.0  24.529620      0.501213    MIN
# ML4     1992.0  24.401134      0.484767    ML4
# MON     1992.0  16.227678      0.545706    MON
# NYA     1992.0  34.831211      0.496733    NYA
# NYN     1992.0  33.783017      0.467071    NYN
# ...
